# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from collections import Counter

# %%
population=np.random.binomial(20,.4,1000)

# %%
Counter(population).keys()
# Out:
# dict_keys([6, 12, 9, 11, 10, 7, 13, 8, 4, 5, 16, 14, 3, 2])

# %%
plt.hist(population)
# Out:
# (array([ 17.,  42., 179., 157., 177., 289.,  77.,  53.,   8.,   1.]),
#  array([ 2. ,  3.4,  4.8,  6.2,  7.6,  9. , 10.4, 11.8, 13.2, 14.6, 16. ]),
#  <a list of 10 Patch objects>)

# %%
np.std(population)
# Out:
# 2.2510610831339073

# %%
np.mean(population)
# Out:
# 8.082

# %%
sample_means=[]
for x in range(1,5000):
    sample=np.random.choice(population,size=int(.30*len(population)),replace=False)
    sample_means.append(np.mean(sample))

# %%
sample_means
# Out:
# [8.1,
#  8.096666666666666,
#  8.016666666666667,
#  7.986666666666666,
#  8.043333333333333,
#  8.2,
#  8.27,
#  8.036666666666667,
#  7.956666666666667,
#  8.103333333333333,
#  8.053333333333333,
#  8.256666666666666,
#  8.123333333333333,
#  7.953333333333333,
#  8.22,
#  8.15,
#  7.736666666666666,
#  8.016666666666667,
#  8.05,
#  8.073333333333334,
#  8.2,
#  8.143333333333333,
#  8.04,
#  7.943333333333333,
#  7.996666666666667,
#  7.943333333333333,
#  8.046666666666667,
#  8.113333333333333,
#  8.076666666666666,
#  8.176666666666666,
#  8.08,
#  8.34,
#  8.11,
#  8.306666666666667,
#  8.163333333333334,
#  8.28,
#  8.07,
#  8.033333333333333,
#  8.016666666666667,
#  8.146666666666667,
#  7.8966666666666665,
#  8.256666666666666,
#  7.886666666666667,
#  8.153333333333334,
#  8.186666666666667,
#  8.0,
#  7.99,
#  8.103333333333333,
#  8.213333333333333,
#  8.123333333333333,
#  8.12,
#  8.076666666666666,
#  8.24,
#  7.97,
#  8.176666666666666,
#  8.09,
#  8.07,
# ...

# %%
means_of_sample_mean=np.mean(sample_means)
poulation_mean=np.mean(population)

# %%
means_of_sample_mean
# Out:
# 8.083742081749683

# %%
plt.hist(sample_means)
# Out:
# (array([  10.,   82.,  365.,  927., 1458., 1260.,  641.,  212.,   40.,
#            4.]),
#  array([7.69      , 7.77233333, 7.85466667, 7.937     , 8.01933333,
#         8.10166667, 8.184     , 8.26633333, 8.34866667, 8.431     ,
#         8.51333333]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(sample_means)
